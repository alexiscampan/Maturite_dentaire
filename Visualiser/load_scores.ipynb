# %%
from pickle import dump, load
import os 

def load_scores(base_path, models):
    score_list = []
    loaded_models = {}
    for model in models:
        with open(os.path.join(base_path, model), "rb") as trained_model:
            loaded = load(trained_model)
            loaded_models[model]=loaded
        try:
            scores = loaded["scores"]
            meta = model.split("_")

            scores["raw_path"] = model
            scores["model"] = meta[0]
            scores["dataset"] = meta[1]
            scores["kind"] = meta[2]

            score_list.append(scores)
        except:
            print("model without scores")
    return score_list, loaded_models

# %%
models = list(os.walk("/home/jovyan/work/model_dump"))[0][2]

# %%
scores=load_scores("/home/jovyan/work/model_dump", models)
# Out:
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
scores
# Out:
# ([          train       val      test  difference  \
#   rmsle -0.003631 -0.019528 -0.018485    0.015896
#   rmse   0.544829  3.844387  3.110626   -3.299558
#   mae    0.451289  1.195997  1.160492   -0.744708
#
#                                                   raw_path model     dataset  \
#   rmsle  rf_knnImputed_baseline_squared_error_True_-0.0...    rf  knnImputed
#   rmse   rf_knnImputed_baseline_squared_error_True_-0.0...    rf  knnImputed
#   mae    rf_knnImputed_baseline_squared_error_True_-0.0...    rf  knnImputed
#
#              kind
#   rmsle  baseline
#   rmse   baseline
#   mae    baseline  ,
#             train       val      test  difference  \
#   rmsle -0.010712 -0.018968 -0.014162    0.008256
#   rmse   1.879315  3.719101  2.453610   -1.839786
#   mae    0.900064  1.195964  1.075705   -0.295900
#
#                                                   raw_path model     dataset  \
#   rmsle  xgb_knnImputed_grid_reg:squarederror_True_-1.1...   xgb  knnImputed
#   rmse   xgb_knnImputed_grid_reg:squarederror_True_-1.1...   xgb  knnImputed
#   mae    xgb_knnImputed_grid_reg:squarederror_True_-1.1...   xgb  knnImputed
#
#          kind
#   rmsle  grid
#   rmse   grid
#   mae    grid  ,
#             train       val      test  difference  \
#   rmsle -0.010712 -0.018968 -0.014162    0.008256
#   rmse   1.879315  3.719101  2.453610   -1.839786
#   mae    0.900064  1.195964  1.075705   -0.295900
#
#                                                   raw_path model     dataset  \
#   rmsle  xgb_knnImputed_refit_reg:squarederror_True_-1....   xgb  knnImputed
#   rmse   xgb_knnImputed_refit_reg:squarederror_True_-1....   xgb  knnImputed
#   mae    xgb_knnImputed_refit_reg:squarederror_True_-1....   xgb  knnImputed
#
#           kind
#   rmsle  refit
#   rmse   refit
#   mae    refit  ,
#             train       val      test  difference  \
#   rmsle -0.009396 -0.018898 -0.013915    0.009502
#   rmse   1.688238  3.681908  2.377202   -1.993670
#   mae    0.880001  1.215083  1.065262   -0.335082
#
#                                                   raw_path model     dataset  \
#   rmsle  xgb_knnImputed_baseline_reg:squarederror_True_...   xgb  knnImputed
#   rmse   xgb_knnImputed_baseline_reg:squarederror_True_...   xgb  knnImputed
#   mae    xgb_knnImputed_baseline_reg:squarederror_True_...   xgb  knnImputed
#
#              kind
#   rmsle  baseline
#   rmse   baseline
#   mae    baseline  ,
#             train       val      test  difference  \
#   rmsle -0.014775 -0.019120 -0.014019    0.004345
#   rmse   2.514998  3.668528  2.399342   -1.153530
#   mae    1.076440  1.208565  1.071130   -0.132125
#
#                                                   raw_path model     dataset  \
#   rmsle  rf_knnImputed_grid_squared_error_True_-1.20711...    rf  knnImputed
#   rmse   rf_knnImputed_grid_squared_error_True_-1.20711...    rf  knnImputed
#   mae    rf_knnImputed_grid_squared_error_True_-1.20711...    rf  knnImputed
#
#          kind
#   rmsle  grid
#   rmse   grid
#   mae    grid  ],
#  {'rf_knnImputed_baseline_squared_error_True_-0.01953_07-02-2022_22:07:54.pkl': {'scaled': True,
#    'categorical': False,
#    'columns_used': array(['num_cols__x0', 'num_cols__x1', 'num_cols__x2', 'num_cols__x3',
#           'num_cols__x4', 'num_cols__x5', 'num_cols__x6', 'num_cols__x7',
#           'num_cols__x8', 'num_cols__x9'], dtype=object),
#    'preprocess': Pipeline(steps=[('col_trans',
#                     ColumnTransformer(n_jobs=6, remainder='passthrough',
#                                       transformers=[('num_cols', StandardScaler(),
#                                                      array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#            True]))])),
#                    ('imputer', KNNImputer())]),
#    'model': RandomForestRegressor(),
#    'preprocessing_path': 'scale_dump/ColumnTransformer_knnImputed_07-02-2022_22:07:54.pkl',
#    'scores':           train       val      test  difference  \
#    rmsle -0.003631 -0.019528 -0.018485    0.015896
#    rmse   0.544829  3.844387  3.110626   -3.299558
#    mae    0.451289  1.195997  1.160492   -0.744708
#
#                                                    raw_path model     dataset  \
#    rmsle  rf_knnImputed_baseline_squared_error_True_-0.0...    rf  knnImputed
#    rmse   rf_knnImputed_baseline_squared_error_True_-0.0...    rf  knnImputed
#    mae    rf_knnImputed_baseline_squared_error_True_-0.0...    rf  knnImputed
#
#               kind
#    rmsle  baseline
#    rmse   baseline
#    mae    baseline  },
#   'xgb_knnImputed_grid_reg:squarederror_True_-1.18114_07-02-2022_22:07:54.pkl': {'scaled': True,
#    'categorical': False,
#    'columns_used': array(['num_cols__x0', 'num_cols__x1', 'num_cols__x2', 'num_cols__x3',
#           'num_cols__x4', 'num_cols__x5', 'num_cols__x6', 'num_cols__x7',
#           'num_cols__x8', 'num_cols__x9'], dtype=object),
#    'preprocess': ColumnTransformer(n_jobs=6, remainder='passthrough',
#                      transformers=[('num_cols', StandardScaler(),
#                                     array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#            True]))]),
#    'model': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#                 gamma=0, gpu_id=-1, importance_type=None,
#                 interaction_constraints='', lambda=1, learning_rate=0.02,
#                 max_delta_step=0, max_depth=6, min_child_weight=5, missing=nan,
#                 monotone_constraints='()', n_estimators=700, n_jobs=1,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#                 validate_parameters=1, verbosity=None),
#    'preprocessing_path': 'scale_dump/ColumnTransformer_knnImputed_07-02-2022_22:07:54.pkl',
#    'scores':           train       val      test  difference  \
#    rmsle -0.010712 -0.018968 -0.014162    0.008256
#    rmse   1.879315  3.719101  2.453610   -1.839786
#    mae    0.900064  1.195964  1.075705   -0.295900
#
#                                                    raw_path model     dataset  \
#    rmsle  xgb_knnImputed_grid_reg:squarederror_True_-1.1...   xgb  knnImputed
#    rmse   xgb_knnImputed_grid_reg:squarederror_True_-1.1...   xgb  knnImputed
#    mae    xgb_knnImputed_grid_reg:squarederror_True_-1.1...   xgb  knnImputed
#
#           kind
#    rmsle  grid
#    rmse   grid
#    mae    grid  },
#   'xgb_knnImputed_refit_reg:squarederror_True_-1.18114_07-02-2022_22:07:54.pkl': {'scaled': True,
#    'categorical': False,
#    'columns_used': array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#            True]),
#    'preprocess': ColumnTransformer(n_jobs=6, remainder='passthrough',
#                      transformers=[('num_cols', StandardScaler(),
#                                     array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#            True]))]),
#    'model': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#                 gamma=0, gpu_id=-1, importance_type=None,
#                 interaction_constraints='', lambda=1, learning_rate=0.02,
#                 max_delta_step=0, max_depth=6, min_child_weight=5, missing=nan,
#                 monotone_constraints='()', n_estimators=700, n_jobs=1,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#                 validate_parameters=1, verbosity=None),
#    'preprocessing_path': 'scale_dump/ColumnTransformer_knnImputed_07-02-2022_22:07:54.pkl',
#    'scores':           train       val      test  difference  \
#    rmsle -0.010712 -0.018968 -0.014162    0.008256
#    rmse   1.879315  3.719101  2.453610   -1.839786
#    mae    0.900064  1.195964  1.075705   -0.295900
#
#                                                    raw_path model     dataset  \
#    rmsle  xgb_knnImputed_refit_reg:squarederror_True_-1....   xgb  knnImputed
#    rmse   xgb_knnImputed_refit_reg:squarederror_True_-1....   xgb  knnImputed
#    mae    xgb_knnImputed_refit_reg:squarederror_True_-1....   xgb  knnImputed
#
#            kind
#    rmsle  refit
#    rmse   refit
#    mae    refit  },
#   'xgb_knnImputed_baseline_reg:squarederror_True_-0.0189_07-02-2022_22:07:54.pkl': {'scaled': True,
#    'categorical': False,
#    'columns_used': array(['num_cols__x0', 'num_cols__x1', 'num_cols__x2', 'num_cols__x3',
#           'num_cols__x4', 'num_cols__x5', 'num_cols__x6', 'num_cols__x7',
#           'num_cols__x8', 'num_cols__x9'], dtype=object),
#    'preprocess': ColumnTransformer(n_jobs=6, remainder='passthrough',
#                      transformers=[('num_cols', StandardScaler(),
#                                     array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#            True]))]),
#    'model': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#                 gamma=0, gpu_id=-1, importance_type=None,
#                 interaction_constraints='', learning_rate=0.02, max_delta_step=0,
#                 max_depth=6, min_child_weight=1, missing=nan,
#                 monotone_constraints='()', n_estimators=700, n_jobs=1,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#                 validate_parameters=1, verbosity=None),
#    'preprocessing_path': 'scale_dump/ColumnTransformer_knnImputed_07-02-2022_22:07:54.pkl',
#    'scores':           train       val      test  difference  \
#    rmsle -0.009396 -0.018898 -0.013915    0.009502
#    rmse   1.688238  3.681908  2.377202   -1.993670
#    mae    0.880001  1.215083  1.065262   -0.335082
#
#                                                    raw_path model     dataset  \
#    rmsle  xgb_knnImputed_baseline_reg:squarederror_True_...   xgb  knnImputed
#    rmse   xgb_knnImputed_baseline_reg:squarederror_True_...   xgb  knnImputed
#    mae    xgb_knnImputed_baseline_reg:squarederror_True_...   xgb  knnImputed
#
#               kind
#    rmsle  baseline
#    rmse   baseline
#    mae    baseline  },
#   'rf_knnImputed_grid_squared_error_True_-1.20711_07-02-2022_22:07:54.pkl': {'scaled': True,
#    'categorical': False,
#    'columns_used': array(['num_cols__x0', 'num_cols__x1', 'num_cols__x2', 'num_cols__x3',
#           'num_cols__x4', 'num_cols__x5', 'num_cols__x6', 'num_cols__x7',
#           'num_cols__x8', 'num_cols__x9'], dtype=object),
#    'preprocess': Pipeline(steps=[('col_trans',
#                     ColumnTransformer(n_jobs=6, remainder='passthrough',
#                                       transformers=[('num_cols', StandardScaler(),
#                                                      array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#            True]))])),
#                    ('imputer', KNNImputer())]),
#    'model': RandomForestRegressor(max_depth=6, max_leaf_nodes=36),
#    'preprocessing_path': 'scale_dump/ColumnTransformer_knnImputed_07-02-2022_22:07:54.pkl',
#    'scores':           train       val      test  difference  \
#    rmsle -0.014775 -0.019120 -0.014019    0.004345
#    rmse   2.514998  3.668528  2.399342   -1.153530
#    mae    1.076440  1.208565  1.071130   -0.132125
#
#                                                    raw_path model     dataset  \
#    rmsle  rf_knnImputed_grid_squared_error_True_-1.20711...    rf  knnImputed
#    rmse   rf_knnImputed_grid_squared_error_True_-1.20711...    rf  knnImputed
#    mae    rf_knnImputed_grid_squared_error_True_-1.20711...    rf  knnImputed
#
#           kind
#    rmsle  grid
#    rmse   grid
#    mae    grid  }})
